# %%
# install the openai module using pip
# pip install openai

# %% [markdown]
# ##### Importing Required Libraries

# %%
import pandas as pd
import os
import openai
import random
import glob
import re
import numpy as np
print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Importing Performance Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ##### Setting OpenAI API Key to Access GPT-3 Model Services

# %%
openai.api_key = "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"

# %% [markdown]
# ### Dataset preparation

# %%
base_path = './'

# %%
# Relative paths to create variables that point to the CSV files
covid_lies_original = os.path.join(base_path, 'Original_dataset', 'covid-19.csv')
fake_news_original = os.path.join(base_path, 'Original_dataset', 'fake_news.csv')

# %%
# read the CSV files into pandas dataframes
df_covid_original = pd.read_csv(covid_lies_original)
df_news_original = pd.read_csv(fake_news_original)

# %%
df_covid_original.head(3) #return the first 3 rows of the dataframes
# Out:
#    id                                              tweet label
# 0   1  Our daily update is published. States reported...  real
# 1   2             Alfalfa is the only cure for COVID-19.  fake
# 2   3  President Trump Asked What He Would Do If He W...  fake

# %%
df_news_original.head(3) #return the first 3 rows of the dataframes
# Out:
#                                            Statement  label
# 0  We have less Americans working now than in the...  FALSE
# 1  When Obama was sworn into office, he DID NOT u...  FALSE
# 2  Says Having organizations parading as being so...  FALSE

# %% [markdown]
# ##### Modifying the structure of the dataframes for our needs

# %%
# Covid Dataset

columns_to_remove = ['id']

#remove columns and create new DataFrame
new_df_covid_original = df_covid_original.drop(columns_to_remove, axis=1) 

# Define the old column name and the new column name
old_column_name = "tweet"
new_column_name = "post"

# Change the column name
new_df_covid_original.rename(columns={old_column_name: new_column_name}, inplace=True)

# replace the values in the 'label' column of dataframe with new values
new_df_covid_original['label'] = new_df_covid_original['label'].replace('real', 'Truth')
new_df_covid_original['label'] = new_df_covid_original['label'].replace('fake', 'Deception')
new_df_covid_original.head()
# Out:
#                                                 post      label
# 0  Our daily update is published. States reported...      Truth
# 1             Alfalfa is the only cure for COVID-19.  Deception
# 2  President Trump Asked What He Would Do If He W...  Deception
# 3  States reported 630 deaths. We are still seein...      Truth
# 4  This is the sixth time a global health emergen...      Truth

# %%
# Fake news Dataset

old_column_name = "Statement"
new_column_name = "post"

# Change the columns name
df_news_original.rename(columns={old_column_name: new_column_name}, inplace=True)

# replace the values in the 'label' column of dataframe with new values
df_news_original['label'] = df_news_original['label'].replace('TRUE', 'Truth')
df_news_original['label'] = df_news_original['label'].replace('FALSE', 'Deception')
df_news_original.head(5)
# Out:
#                                                 post      label
# 0  We have less Americans working now than in the...  Deception
# 1  When Obama was sworn into office, he DID NOT u...  Deception
# 2  Says Having organizations parading as being so...  Deception
# 3     Says nearly half of Oregons children are poor.      Truth
# 4  On attacks by Republicans that various program...      Truth

# %% [markdown]
# ##### Distribution of values

# %%
new_df_covid_original['label'].value_counts()
# Out:
# Truth        1120
# Deception    1020
# Name: label, dtype: int64

# %%
df_news_original['label'].value_counts()
# Out:
# Truth        1336
# Deception    1232
# Label           1
# Name: label, dtype: int64

# %% [markdown]
# #### text cleaning

# %%
def clean_text(text):
    text = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)  # Remove URLs
    text = re.sub('[@&]\w+', '', text)  # Remove words starting with @ and &
    text = re.sub('#\w+', '', text)  # Remove hashtags
    text = re.sub('\?+', '', text)  # Remove question marks
    text = re.sub('[\u2713\u2717]', '', text)  # Remove tick and cross signs
    text = re.sub('[\U0001F300-\U0001F5FF\U0001F600-\U0001F64F\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U0001F926-\U0001F937\U0001F1E6-\U0001F1FF\U0001F191-\U0001F19A\U0000231A-\U0000231B\U00002328-\U000023FA\U0001F30D-\U0001F30F\U0001F315-\U0001F315\U0001F31C-\U0001F31C\U0001F321-\U0001F321]', '', text)  # Remove emojis
    return text

new_df_covid_original['post'] = new_df_covid_original['post'].apply(clean_text)

# %%
new_df_covid_original = new_df_covid_original.drop_duplicates(subset='post')
df_news_original = df_news_original.drop_duplicates(subset='post')

# %%
new_df_covid_original['label'].value_counts()
# Out:
# Truth        1118
# Deception    1017
# Name: label, dtype: int64

# %%
df_news_original['label'].value_counts()
# Out:
# Truth        668
# Deception    616
# Label          1
# Name: label, dtype: int64

# %% [markdown]
# #### Remove web link from the post

# %%
new_df_covid_original['post'] = new_df_covid_original['post'].str.replace(r'http\S+|www.\S+', '', case=False)
# Out:
# /tmp/ipykernel_70373/1130230404.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df_covid_original['post'] = new_df_covid_original['post'].str.replace(r'http\S+|www.\S+', '', case=False)

# %%
new_df_covid_original['label'].value_counts()
# Out:
# Truth        1118
# Deception    1017
# Name: label, dtype: int64

# %% [markdown]
# #### Creating Truth and Deception Datasets

# %% [markdown]
# ##### Truth Covid Dataset

# %%
# a random sample of 250 rows from corona dataset where the value in the 'label' column is 'Truth'
covid_truth = new_df_covid_original.loc[new_df_covid_original['label']=='Truth'].sample(n=250)
covid_truth['label'].value_counts()
# Out:
# Truth    250
# Name: label, dtype: int64

# %%
# save the truth covid dataset in a csv file
covid_truth.to_csv(os.path.join(base_path,'selected_dataset','covid_truth.csv'),index=False)

# %% [markdown]
# ##### Deception Covid Dataset

# %%
# a random sample of 250 rows from corona dataset where the value in the 'label' column is 'Deception'
covid_deception = new_df_covid_original.loc[new_df_covid_original['label']=='Deception'].sample(n=250)
covid_deception['label'].value_counts()
# Out:
# Deception    250
# Name: label, dtype: int64

# %%
# save the deceptive covid dataset in a csv file
covid_deception.to_csv(os.path.join(base_path,'selected_dataset','covid_deception.csv'),index=False)

# %% [markdown]
# ##### Truth News Dataset

# %%
# a random sample of 250 rows from news dataset where the value in the 'label' column is 'Truth'
news_truth = df_news_original.loc[df_news_original['label']=='Truth'].sample(n=250)
news_truth['label'].value_counts()
# Out:
# Truth    250
# Name: label, dtype: int64

# %%
# save the truth news dataset in a csv file
news_truth.to_csv(os.path.join(base_path,'selected_dataset','news_truth.csv'),index=False)

# %% [markdown]
# ##### Deception News Dataset

# %%
# a random sample of 250 rows from news dataset where the value in the 'label' column is 'Deception'
news_deception = df_news_original.loc[df_news_original['label']=='Deception'].sample(n=250)
news_deception['label'].value_counts()
# Out:
# Deception    250
# Name: label, dtype: int64

# %%
# save the deceptive news dataset in a csv file
news_deception.to_csv(os.path.join(base_path,'selected_dataset','news_deception.csv'),index=False)

# %% [markdown]
# ##### Merging Datasets

# %%
# the path for joining multiple files
files = os.path.join(base_path,'selected_dataset', "*.csv")

# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...")
# Out:
# Resultant CSV after joining all CSV files at a particular location...

# %%
# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df.to_csv(os.path.join(base_path,'selected_dataset','merged_dataset.csv'), index=False)

# %%
df['label'].value_counts()
# Out:
# Truth        7530
# Deception    7530
# Name: label, dtype: int64

# %%
len(df)
# Out:
# 15060

# %% [markdown]
# ### Full Datset Formation

# %%
# Read the CSV file
dataset_selected = pd.read_csv(os.path.join(base_path,'selected_dataset','merged_dataset.csv'))
dataset_selected.head()
# Out:
#                                                 post  label
# 0  :  India Tracker (As on 06 September 2020 08:0...  Truth
# 1  : India registers Recoveries of 65081 in the l...  Truth
# 2  A small fraction of deaths in long-term care f...  Truth
# 3   Following the national trend 17 States/UTs ha...  Truth
# 4  Update from the  There are three new cases of ...  Truth

# %%
# Separate the two classes
class_1 = dataset_selected[dataset_selected['label'] == 'Deception']
class_2 = dataset_selected[dataset_selected['label'] == 'Truth']

# Randomly select 5 samples from each class
class_1_samples = class_1.sample(n=500, random_state=42)
class_2_samples = class_2.sample(n=500, random_state=42)

# Combine the selected samples
selected_samples = pd.concat([class_1_samples, class_2_samples])

# Save the selected samples to a new CSV file
selected_samples.to_csv(os.path.join(base_path,'selected_dataset','full_dataset.csv'), index=False)

# %%
# Read the CSV file
full_dataset = pd.read_csv(os.path.join(base_path,'selected_dataset','full_dataset.csv'), index_col=None)
full_dataset.head(10)
# Out:
#                                                 post      label
# 0     Lucky for you grapefruit doesn’t make quini...  Deception
# 1  Nevada Democratic Party leaders hijacked the p...  Deception
# 2  Says a group estimates that the annual cost to...  Deception
# 3  There is long historical precedent for a Supre...  Deception
# 4  Says Chuck Hagel has called for an end to our ...  Deception
# 5  A claim that the novel coronavirus was never d...  Deception
# 6  Action by the Milwaukee County Board will prov...  Deception
# 7  Toledo is fourth in the nation behind much big...  Deception
# 8  After Fahrenheit 9/11 came out, "Bush's approv...  Deception
# 9  An analysis showed that Bernie Sanders would h...  Deception

# %%
full_dataset['label'].value_counts()
# Out:
# Deception    500
# Truth        500
# Name: label, dtype: int64

# %% [markdown]
# ## GPT-3 Classification

# %%
#arguments:

    #1. prompt - string represting the text prompt for the language model to complete
    #2. model - name of the OpenAI GPT-3 langauge model to use for text classification
    #3. n - integer that specifies the number of responses to return from the OpenAI API
    
def classify_text(prompt):
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Label the text as 'Deception' or 'Truth'"},
            {"role": "user", "content": prompt}
        ],
        max_tokens=10,
        temperature=0.5,
        stop=["."]
    )
    prediction = completion.choices[0].message['content'].strip()
    label = prediction.split()[0]
    return label

# %% [markdown]
# ## Zero-shot Classification

# %%
# Perform a Zero Shot Classification on the full_dataset

prompt_zero_shot = "Is the following socila media post either Deception or Truth? \"{}\""
zeroshot_actual_label_list = []
zeroshot_predicted_label_list = []

# iterate through each row of the full_dataset
for i in range(0, len(full_dataset)):
    print('sample number :', i)
    sample_post = full_dataset.loc[i]
    print('Sample Post: ',sample_post['post'])
    prompt = prompt_zero_shot.format(sample_post['post'])
    result = classify_text(prompt)
    print(f"Actual Label: {sample_post['label']}")
    print(f"Predicted Label: {result}")
    zeroshot_actual_label_list.append(sample_post['label'])
    zeroshot_predicted_label_list.append(result)

    
results = pd.DataFrame({'Actual': zeroshot_actual_label_list, 'Predicted': zeroshot_predicted_label_list})

# Save the DataFrame to a CSV file
output_file = 'zeroshot_results.csv'
results.to_csv(os.path.join(base_path,'result_zero_shot',output_file), index=False)
# Out:
# sample number : 0
# Sample Post:     Lucky for you grapefruit doesn’t make quinine. Hydtoxychloroquine is a different chemical. You’re not getting any.
# Both are somewhat effective anti-malarial treatments but have side effects.
# They have no effect on SARS-CoV-2 virus that causes Covid-19.
#
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 1
# Sample Post:  Nevada Democratic Party leaders hijacked the process on the floor of the state convention ignoring the regular procedure and ramming through what they wanted to do.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 2
# Sample Post:  Says a group estimates that the annual cost to Oregon taxpayers for government services to illegal aliens, after any income tax revenue from them, is $1 billion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 3
# Sample Post:  There is long historical precedent for a Supreme Court with fewer justices.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 4
# Sample Post:  Says Chuck Hagel has called for an end to our nuclear program.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 5
# Sample Post:  A claim that the novel coronavirus was never detected in the major Chinese cities of Beijing and Shanghai has been shared repeatedly on Facebook Twitter and Instagram.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 6
# Sample Post:  Action by the Milwaukee County Board will provide the County Executive with the same level of security as the Governor and the Mayor of Milwaukee while saving taxpayers $300,000.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 7
# Sample Post:  Toledo is fourth in the nation behind much bigger cities Miami, Las Vegas, Portland in number of human trafficking arrests and rescues.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 8
# Sample Post:  After Fahrenheit 9/11 came out, "Bush's approval rating never was better, it only got worse."
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 9
# Sample Post:  An analysis showed that Bernie Sanders would have won the Democratic nomination if it were not for the Super Delegates.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 10
# Sample Post:  Back in the Great Recession, when millions of jobs across America hung in the balance, Donald Trump said rescuing the auto industry didnt really matter very much. He said, and I quote again, Let it go.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 11
# Sample Post:  Bank of America could create 878,300 jobs with benefits if they spent their 2010 bonuses on job creation.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 12
# Sample Post:  Says only about 2 percent of gunsales in Virginia are not subject to background checks.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 13
# Sample Post:  Video of migrants in a overcrowded train from Mumbai to West Bengal on 10 May 2020 amid COVID-19 social distancing restrictictions.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 14
# Sample Post:  Tinder Adds New “COVID-19 Positive” Option For Users
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 15
# Sample Post:  Great Idea for Mass Steam Inhalation during this
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 16
# Sample Post:  In 2009, Jim Doyle and the Democrats rushed through a budget repair bill with billions in tax increases and held no public hearings.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 17
# Sample Post:  She is the only candidate who has stood by our community and immigration reform from the beginning.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 18
# Sample Post:  A police officer in Bihar's Hajipur jail has been affected with coronavirus.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 19
# Sample Post:  Obama's one education accomplishment was "legislation to teach 'comprehensive sex education' to kindergartners."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 20
# Sample Post:  Saddam Hussein at a meeting in the nineties reported that the US threatened to quit the Corona virus on Iraq
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 21
# Sample Post:  Ukraine was a nuclear-armed state. They gave away their nuclear arms with the understanding that we would protect them.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 22
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 23
# Sample Post:  With a stroke of a pen, the (U.S. Supreme Court) decided to overrule the 100-year-old ban on corporate expenditures.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 24
# Sample Post:  Says that under President Barack Obamas health care law, your insurance premiums could go up by 200 percent and cost as much as a new Explorer.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 25
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 26
# Sample Post:  Donald Trumps been completely consistent about his plan for nonviolent undocumented immigrants.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 27
# Sample Post:  Now, theyre doing tests on airlines " very strong tests " for getting on, getting off. Theyre doing tests on trains " getting on, getting off.�
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 28
# Sample Post:  The Government Accountability Office estimated (Obamacare) will add to the long-term deficit by $6.2 trillion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 29
# Sample Post:  In the second consecutive day India reports over 50000 new infections taking the overall confirmed case tally to 16.3 lakh. Directorate General of Civil Aviation extends the suspension of commercial international flights to India till 31 August.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 30
# Sample Post:  _A video has been viewed thousands of times in multiple posts on Facebook Twitter and YouTube in May 2020 alongside a claim it shows crows coming to Texas� after attacking Wuhan China�. The posts were shared as countries worldwide continue to fight the spread of the novel coronavirus which was first detected in Wuhan in December 2019._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 31
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 32
# Sample Post:  Everyone knows that we're facing a real crisis from the coronavirus. But do you know how we got here and what we need to do next Ron Klain, former White House Ebola Response Coordinator, breaks it down for us:
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 33
# Sample Post:  Bob Menendez actually voted in favor of higher taxes more than 70 times!
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 34
# Sample Post:  Oklahoma 100% coronavirus test rate after Trump Tulsa rally.�
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 35
# Sample Post:  President Barack Obama is the first president to keep a dog-trainer on retainer for $102,000 a year at taxpayer expense.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 36
# Sample Post:  In the Florida Republican primary, "we got a very large percentage of the, quote, conservative vote."
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 37
# Sample Post:  Dr. VK Srinivas Vice-President of Bharath Biotech He is taking first injection of COVID 19 vaccine. They have confidence in their product
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 38
# Sample Post:  Good people of Twitter, and especially those with young children. If you or your partner have had symptoms during the lockdown, which best describes your approach:
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 39
# Sample Post:  Dr. Li Wenliang (the Chinese whistleblower doctor) has proposed that drinking tea can cure COVID-19.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 40
# Sample Post:  Holly Turner... still takes her homestead (property tax) exemption in Fort Worth.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 41
# Sample Post:  In December 2019 Italian politician Beppe Grillo wore a protective mask in public. Some people said that he did that because the Chinese Embassy had warned him about coronavirus.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 42
# Sample Post:  Italy finds home remedy for Covid’19 / 500gms aspirin dissolved with lemon juice boiled with honey, it is taken hot.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 43
# Sample Post:     Sir i was infected in mid August of covid 19 and after suffering for 8 days was prescribed for Favipiravir fabiflu and was cured.
# In 36 hours most of my symptoms were gone fully recovered in 7 days
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 44
# Sample Post:  I also voted 98 percent of the time with Republicans in the Oregon Legislature.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 45
# Sample Post:  Decision of lockdown was timely, curve has begun to flatten
#
# The nation has shown that lockdown has been effective, , containing  infection and slowing down doubling rate
#
# We need to build on these gains
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 46
# Sample Post:  Italian doctors say coronavirus is bacteria.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 47
# Sample Post:  A person with a cold or flu will test positive for COVID-19
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 48
# Sample Post:  This virus must be old because the label on a bottle of disinfectant from 2015 shows "coronavirus“.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 49
# Sample Post:  Newgard owed more than $13,000 for unpaid taxes on his $1 million Milwaukie apartment complex.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 50
# Sample Post:  Following the catastrophic, cascading collapse of major investment banks on Wall Street in 2007.....Nobody was prosecuted, no hearings were held and no reforms were implemented.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 51
# Sample Post:  Meditate Your Way Through Covid 19 With Tracy Honeycomb
#
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 52
# Sample Post:  Honduras's first confirmed case traveled to Taiwan earlier which means there is a severe community transmission in Taiwan.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 53
# Sample Post:  The only reason the unemployment rate is going down is because twice as many people dropped out of the employment pool as the number of jobs were created.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 54
# Sample Post:  She hasn't run a corner store. She hasn't run a state. She hasn't run a city. She has never run anything.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 55
# Sample Post:  Videos show pigs being buried in China due to the coronavirus outbreak.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 56
# Sample Post:  _A vaccine has been developed that cures Covid-19 in just three hours._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 57
# Sample Post:  The job [of correctional officer] lowers your life expectancy . . . Metropolitan did a study in, I believe it was 1998, and the life expectancy was 58.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 58
# Sample Post:  In the health care bill, were now offering insurance for dogs.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 59
# Sample Post:  In Catherine Cortez Mastos last term as attorney general, Nevada murder went up 11 percent, robbery went up 28 percent, rape 51 percent. When Cortez Masto left office, Nevada ranked as Americas third most dangerous state.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 60
# Sample Post:  Four million women have fallen into poverty in the last six years.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 61
# Sample Post:  Strange coincidence that all worst affected Covid19 cases are along the same Latitude 40ํ :
# From left:
# France Italy Iran Wuhan S.Korea Japan Seattle Washington NewYork.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 62
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 63
# Sample Post:  The U.S. wont default, because default means that you dont pay your creditors. And it takes about 10 percent of the money thats coming in right now to pay interest to bondholders.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 64
# Sample Post:  Trump says if we stopped COVID-19 testing right now we’d have very few cases if any. Pants on Fire!
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 65
# Sample Post:  We will all come out stronger from this   . Just
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 66
# Sample Post:  Squeezing hot lemon water cures corona virus infection.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 67
# Sample Post:  We dont allow filming inside of the City Hall unless there is a specific reason.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 68
# Sample Post:  Under Gov. Scott Walker, employer confidence now stands at 95 percent, compared to only 10 percent at the end of the Gov. Jim Doyle-Mary Burke administration.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 69
# Sample Post:  The health care reform plan would set limits similar to the socialized system in Britain, where people are allowed to die if their treatment would cost more than $22,000.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 70
# Sample Post:  The Dodd-Frank financial-reform laws hundreds of new rules will force small banks and credit unions to burn up an estimated 2,260,631 labor hours just for compliance.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 71
# Sample Post:  Four million women have fallen into poverty in the last six years.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 72
# Sample Post:  If people work and make more money, they lose more in benefits than they would earn in salary.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 73
# Sample Post:  The health care reform plan would set limits similar to the socialized system in Britain, where people are allowed to die if their treatment would cost more than $22,000.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 74
# Sample Post:  Purdue Pharma Recommends Oxycontin for Treating Coronavirus Self-Quarantine Symptoms
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 75
# Sample Post:  Donald Trump is not responsible for COVID-19, but he does bear full responsibility for his slow, uncoordinated, bungled response.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 76
# Sample Post:  On climate change, the temperature readings have been fabricated, and its all blowing up in their (scientists) faces.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 77
# Sample Post:  Says the congressional ethics investigation against him was conducted by a very partisan political committee in a way that related more to the politics of the Democratic Party than to ethics.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 78
# Sample Post:  The Senate version of the health care reform bill allows taxpayer money to pay directly for abortion in federal community health centers funded in the bill.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 79
# Sample Post:  Says unlike Tim Kaine, who investedin education, Indiana Gov. Mike Pence slashed education funding.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 80
# Sample Post:  A COVID-19 case has been diagnosed in Umraniye Hospital Istanbul.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 81
# Sample Post:  A poll taken a few months ago found 70 percent approval or higher for the Act 10 collective bargaining law.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 82
# Sample Post:  Says James Langevin voted to spend $3 billion for a jet engine no one wants.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 83
# Sample Post:  The stand your ground lawcaused the shooting death of Trayvon Martin.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 84
# Sample Post:  Covid rashes are now responsible for hate
#
# Covid-19 skin rash website criticised for lack of BAME examples
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 85
# Sample Post:  Prolonged use of the mask causes hypoxia.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 86
# Sample Post:  Says Having organizations parading as being social welfare organizations and then being involved in the political combat harkens back to why the statute a hundred years ago said that they were prohibited.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 87
# Sample Post:  Man Ordered Family Out On Military Manouevres
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 88
# Sample Post:  Tim Kaine announced he wants to raise taxes on everyone.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 89
# Sample Post:  “Putin has stated Russian citizens (have) 2 options Stay home for 15 days or in jail for 5 years.”
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 90
# Sample Post:  Beware Of A Donald Trump Vaccine
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 91
# Sample Post:  UNICEF releases coronavirus prevention guidelines.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 92
# Sample Post:  Channel 4's Jon Snow is infected with coronavirus.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 93
# Sample Post:  A post claims compulsory vacination violates the principles of bioethics that coronavirus doesn't exist that the PCR test returns many false positives and that influenza vaccine is related to COVID-19.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 94
# Sample Post:  The people who were running the budget, in the Corzine years, decided to steal from the unemployment trust fund. As did other Governors before. We simply dont do that, havent done it, and wont permit it.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 95
# Sample Post:      How many FROM covid 19 How many died because New York and New Jersey screwed the elderly Thats all trumps fault right When trump shut down travel...he's a racist. Trump puts a team together to figure out the virus...its not diverse enough.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 96
# Sample Post:  Since some asked about this, am letting know that I am recommending Checkovir after testing on myself for a month. I find it a life saver in allergic rainy season this year. Was part of testing group. I find logical that it will reduce probability of corona due to antiviral layer
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 97
# Sample Post:  Matarratón tree cures COVID-19
# ---------------------------------------------------------------------------
# ServiceUnavailableError                   Traceback (most recent call last)
# /tmp/ipykernel_70373/1865677448.py in <module>
#      11     print('Sample Post: ',sample_post['post'])
#      12     prompt = prompt_zero_shot.format(sample_post['post'])
# ---> 13     result = classify_text(prompt)
#      14     print(f"Actual Label: {sample_post['label']}")
#      15     print(f"Predicted Label: {result}")
#
# /tmp/ipykernel_70373/3620796271.py in classify_text(prompt)
#       6
#       7 def classify_text(prompt):
# ----> 8     completion = openai.ChatCompletion.create(
#       9         model="gpt-3.5-turbo",
#      10         messages=[
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     296             request_timeout=request_timeout,
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#     300
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     698         else:
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#     702                     result.status_code,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     741
#     742         if rcode == 503:
# --> 743             raise error.ServiceUnavailableError(
#     744                 "The server is overloaded or not ready yet.",
#     745                 rbody,
#
# ServiceUnavailableError: The server is overloaded or not ready yet.

# %% [markdown]
# ### Evaluate Zero-Shot Classification Results on Full Dataset

# %%
results_from_file = pd.read_csv(os.path.join(base_path,'result_zero_shot',output_file))

# Extract the actual and predicted labels from the DataFrame
actual_labels_from_file = results_from_file['Actual'].tolist()
predicted_labels_from_file = results_from_file['Predicted'].tolist()

# Calculate the accuracy, precision, recall, and F1-score
accuracy = accuracy_score(actual_labels_from_file, predicted_labels_from_file)
precision = precision_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
recall = recall_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
f1 = f1_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')

# Print the results
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")


overall_zeroshot_result =[]
overall_zeroshot_result.append(round(accuracy, 2))
overall_zeroshot_result.append(round(precision, 2))
overall_zeroshot_result.append(round(recall, 2))
overall_zeroshot_result.append(round(f1, 2))

# %% [markdown]
# ## Sample Selection for One-shot and Few-shot Classification

# %%
def select_samples(num_samples):
    # Assign the class values
    deceptive_class = 'Deception'
    truthful_class = 'Truth'

    # Separate the data into two classes based on label values
    deceptive_data = full_dataset[full_dataset['label'] == deceptive_class]
    truthful_data = full_dataset[full_dataset['label'] == truthful_class]

    # Randomly select "num_samples" samples from each class
    deceptive_sample = deceptive_data.sample(n=num_samples)
    truthful_sample = truthful_data.sample(n=num_samples)
    
    # Concatenate deceptive and thruthful samples in one DataFrame
    oneshot_samples = pd.concat([deceptive_sample, truthful_sample])

    # Remove the selected samples from the original DataFrame
    remaining_deceptive_data = deceptive_data.drop(deceptive_sample.index)
    remaining_truthful_data = truthful_data.drop(truthful_sample.index)

    # Combine the remaining samples
    remaining_data = pd.concat([remaining_deceptive_data, remaining_truthful_data])

    # Reset the index of the remaining data
    remaining_data.reset_index(drop=True, inplace=True)
    
    return oneshot_samples, remaining_data

# %% [markdown]
# ## One-shot Classification

# %%
    
def oneshot_classify_text(prompt):
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Label the text as 'Deception' or 'Truth'"},
            {"role": "user", "content": prompt}
        ],
        max_tokens=200,
        temperature=0.5,
        stop=[':']
    )
    prediction = completion.choices[0].message['content'].strip()
    label = prediction.split()[0]
    return label

# %%
def one_shot_learning():
    # Initialize empty lists to store actual and predicted labels
    actual_label_list = []
    predicted_label_list = []
    
    # obtain one randomly sample from each class and store in selected_sample 
    # the remaining samples stored in remaining_samples_dataset
    selected_sample, remaining_samples_dataset = select_samples(1)
    
    #seperate the samples based on their label
    deceptive_class_sample = selected_sample[selected_sample['label'] == 'Deception']
    truth_class_sample = selected_sample[selected_sample['label'] == 'Truth']
    
    deceptive_oneshot = deceptive_class_sample['post']
    truth_oneshot = truth_class_sample['post']
    
    prompt_one_shot = (
    f"Below are two social media posts, either Deception or Truth\n"
    f"Deception: {deceptive_oneshot}\n"
    f"Truth: {truth_oneshot}\n"
    )
    print(prompt_one_shot)

    for i in range(0, len(remaining_samples_dataset)):
        print('sample number :', i)
        sample_post = remaining_samples_dataset.loc[i]
        print('Sample Post: ',sample_post['post'])

        prompt = prompt_one_shot.format(sample_post['post'])
        result = oneshot_classify_text(prompt)
        print(f"Actual Label: {sample_post['label']}")
        print(f"Predicted Label: {result}")
        actual_label_list.append(sample_post['label'])
        predicted_label_list.append(result)
    
    return actual_label_list, predicted_label_list

# %%
one_shot_iterations = 3
for i in range(0, one_shot_iterations):
    print('One-Shot Interation :',i)
    act_label_list,  pre_label_list= one_shot_learning()
    results = pd.DataFrame({'Actual': act_label_list, 'Predicted': pre_label_list})

    # Save the DataFrame to a CSV file
    output_file = str(i)+'_'+ 'oneshot_results.csv'
    results.to_csv(os.path.join(base_path,'result_one_shot',output_file), index=False)
# Out:
# One-Shot Interation : 0
# Below are two social media posts, either Deception or Truth
# Deception: 245    Says Gov. Chris Christies proposed budget is t...
# Name: post, dtype: object
# Truth: 736    Only 20 colleges and universities have athleti...
# Name: post, dtype: object
#
# sample number : 0
# Sample Post:     Lucky for you grapefruit doesn’t make quinine. Hydtoxychloroquine is a different chemical. You’re not getting any.
# Both are somewhat effective anti-malarial treatments but have side effects.
# They have no effect on SARS-CoV-2 virus that causes Covid-19.
#
#
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 1
# Sample Post:  Nevada Democratic Party leaders hijacked the process on the floor of the state convention ignoring the regular procedure and ramming through what they wanted to do.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 2
# Sample Post:  Says a group estimates that the annual cost to Oregon taxpayers for government services to illegal aliens, after any income tax revenue from them, is $1 billion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 3
# Sample Post:  There is long historical precedent for a Supreme Court with fewer justices.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 4
# Sample Post:  Says Chuck Hagel has called for an end to our nuclear program.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 5
# Sample Post:  A claim that the novel coronavirus was never detected in the major Chinese cities of Beijing and Shanghai has been shared repeatedly on Facebook Twitter and Instagram.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 6
# Sample Post:  Action by the Milwaukee County Board will provide the County Executive with the same level of security as the Governor and the Mayor of Milwaukee while saving taxpayers $300,000.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 7
# Sample Post:  Toledo is fourth in the nation behind much bigger cities Miami, Las Vegas, Portland in number of human trafficking arrests and rescues.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 8
# Sample Post:  After Fahrenheit 9/11 came out, "Bush's approval rating never was better, it only got worse."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 9
# Sample Post:  An analysis showed that Bernie Sanders would have won the Democratic nomination if it were not for the Super Delegates.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 10
# Sample Post:  Back in the Great Recession, when millions of jobs across America hung in the balance, Donald Trump said rescuing the auto industry didnt really matter very much. He said, and I quote again, Let it go.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 11
# Sample Post:  Bank of America could create 878,300 jobs with benefits if they spent their 2010 bonuses on job creation.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 12
# Sample Post:  Says only about 2 percent of gunsales in Virginia are not subject to background checks.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 13
# Sample Post:  Video of migrants in a overcrowded train from Mumbai to West Bengal on 10 May 2020 amid COVID-19 social distancing restrictictions.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 14
# Sample Post:  Tinder Adds New “COVID-19 Positive” Option For Users
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 15
# Sample Post:  Great Idea for Mass Steam Inhalation during this
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 16
# Sample Post:  In 2009, Jim Doyle and the Democrats rushed through a budget repair bill with billions in tax increases and held no public hearings.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 17
# Sample Post:  She is the only candidate who has stood by our community and immigration reform from the beginning.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 18
# Sample Post:  A police officer in Bihar's Hajipur jail has been affected with coronavirus.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 19
# Sample Post:  Obama's one education accomplishment was "legislation to teach 'comprehensive sex education' to kindergartners."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 20
# Sample Post:  Saddam Hussein at a meeting in the nineties reported that the US threatened to quit the Corona virus on Iraq
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 21
# Sample Post:  Ukraine was a nuclear-armed state. They gave away their nuclear arms with the understanding that we would protect them.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 22
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 23
# Sample Post:  With a stroke of a pen, the (U.S. Supreme Court) decided to overrule the 100-year-old ban on corporate expenditures.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 24
# Sample Post:  Says that under President Barack Obamas health care law, your insurance premiums could go up by 200 percent and cost as much as a new Explorer.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 25
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 26
# Sample Post:  Donald Trumps been completely consistent about his plan for nonviolent undocumented immigrants.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 27
# Sample Post:  Now, theyre doing tests on airlines " very strong tests " for getting on, getting off. Theyre doing tests on trains " getting on, getting off.�
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 28
# Sample Post:  The Government Accountability Office estimated (Obamacare) will add to the long-term deficit by $6.2 trillion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 29
# Sample Post:  In the second consecutive day India reports over 50000 new infections taking the overall confirmed case tally to 16.3 lakh. Directorate General of Civil Aviation extends the suspension of commercial international flights to India till 31 August.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 30
# Sample Post:  _A video has been viewed thousands of times in multiple posts on Facebook Twitter and YouTube in May 2020 alongside a claim it shows crows coming to Texas� after attacking Wuhan China�. The posts were shared as countries worldwide continue to fight the spread of the novel coronavirus which was first detected in Wuhan in December 2019._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 31
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 32
# Sample Post:  Everyone knows that we're facing a real crisis from the coronavirus. But do you know how we got here and what we need to do next Ron Klain, former White House Ebola Response Coordinator, breaks it down for us:
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 33
# Sample Post:  Bob Menendez actually voted in favor of higher taxes more than 70 times!
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 34
# Sample Post:  Oklahoma 100% coronavirus test rate after Trump Tulsa rally.�
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 35
# Sample Post:  President Barack Obama is the first president to keep a dog-trainer on retainer for $102,000 a year at taxpayer expense.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 36
# Sample Post:  In the Florida Republican primary, "we got a very large percentage of the, quote, conservative vote."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 37
# Sample Post:  Dr. VK Srinivas Vice-President of Bharath Biotech He is taking first injection of COVID 19 vaccine. They have confidence in their product
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 38
# Sample Post:  Good people of Twitter, and especially those with young children. If you or your partner have had symptoms during the lockdown, which best describes your approach:
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 39
# Sample Post:  Dr. Li Wenliang (the Chinese whistleblower doctor) has proposed that drinking tea can cure COVID-19.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 40
# Sample Post:  Holly Turner... still takes her homestead (property tax) exemption in Fort Worth.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 41
# Sample Post:  In December 2019 Italian politician Beppe Grillo wore a protective mask in public. Some people said that he did that because the Chinese Embassy had warned him about coronavirus.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 42
# Sample Post:  Italy finds home remedy for Covid’19 / 500gms aspirin dissolved with lemon juice boiled with honey, it is taken hot.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 43
# Sample Post:     Sir i was infected in mid August of covid 19 and after suffering for 8 days was prescribed for Favipiravir fabiflu and was cured.
# In 36 hours most of my symptoms were gone fully recovered in 7 days
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 44
# Sample Post:  I also voted 98 percent of the time with Republicans in the Oregon Legislature.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 45
# Sample Post:  Decision of lockdown was timely, curve has begun to flatten
#
# The nation has shown that lockdown has been effective, , containing  infection and slowing down doubling rate
#
# We need to build on these gains
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 46
# Sample Post:  Italian doctors say coronavirus is bacteria.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 47
# Sample Post:  A person with a cold or flu will test positive for COVID-19
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 48
# Sample Post:  This virus must be old because the label on a bottle of disinfectant from 2015 shows "coronavirus“.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 49
# Sample Post:  Newgard owed more than $13,000 for unpaid taxes on his $1 million Milwaukie apartment complex.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 50
# Sample Post:  Following the catastrophic, cascading collapse of major investment banks on Wall Street in 2007.....Nobody was prosecuted, no hearings were held and no reforms were implemented.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 51
# Sample Post:  Meditate Your Way Through Covid 19 With Tracy Honeycomb
#
#
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 52
# Sample Post:  Honduras's first confirmed case traveled to Taiwan earlier which means there is a severe community transmission in Taiwan.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 53
# Sample Post:  The only reason the unemployment rate is going down is because twice as many people dropped out of the employment pool as the number of jobs were created.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 54
# Sample Post:  She hasn't run a corner store. She hasn't run a state. She hasn't run a city. She has never run anything.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 55
# Sample Post:  Videos show pigs being buried in China due to the coronavirus outbreak.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 56
# Sample Post:  _A vaccine has been developed that cures Covid-19 in just three hours._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 57
# Sample Post:  The job [of correctional officer] lowers your life expectancy . . . Metropolitan did a study in, I believe it was 1998, and the life expectancy was 58.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 58
# Sample Post:  In the health care bill, were now offering insurance for dogs.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 59
# Sample Post:  In Catherine Cortez Mastos last term as attorney general, Nevada murder went up 11 percent, robbery went up 28 percent, rape 51 percent. When Cortez Masto left office, Nevada ranked as Americas third most dangerous state.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 60
# Sample Post:  Four million women have fallen into poverty in the last six years.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 61
# Sample Post:  Strange coincidence that all worst affected Covid19 cases are along the same Latitude 40ํ :
# From left:
# France Italy Iran Wuhan S.Korea Japan Seattle Washington NewYork.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 62
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 63
# Sample Post:  The U.S. wont default, because default means that you dont pay your creditors. And it takes about 10 percent of the money thats coming in right now to pay interest to bondholders.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 64
# Sample Post:  Trump says if we stopped COVID-19 testing right now we’d have very few cases if any. Pants on Fire!
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 65
# Sample Post:  We will all come out stronger from this   . Just
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 66
# Sample Post:  Squeezing hot lemon water cures corona virus infection.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 67
# Sample Post:  We dont allow filming inside of the City Hall unless there is a specific reason.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 68
# Sample Post:  Under Gov. Scott Walker, employer confidence now stands at 95 percent, compared to only 10 percent at the end of the Gov. Jim Doyle-Mary Burke administration.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 69
# Sample Post:  The health care reform plan would set limits similar to the socialized system in Britain, where people are allowed to die if their treatment would cost more than $22,000.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 70
# Sample Post:  The Dodd-Frank financial-reform laws hundreds of new rules will force small banks and credit unions to burn up an estimated 2,260,631 labor hours just for compliance.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 71
# Sample Post:  Four million women have fallen into poverty in the last six years.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 72
# Sample Post:  If people work and make more money, they lose more in benefits than they would earn in salary.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 73
# Sample Post:  The health care reform plan would set limits similar to the socialized system in Britain, where people are allowed to die if their treatment would cost more than $22,000.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 74
# Sample Post:  Purdue Pharma Recommends Oxycontin for Treating Coronavirus Self-Quarantine Symptoms
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 75
# Sample Post:  Donald Trump is not responsible for COVID-19, but he does bear full responsibility for his slow, uncoordinated, bungled response.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 76
# Sample Post:  On climate change, the temperature readings have been fabricated, and its all blowing up in their (scientists) faces.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 77
# Sample Post:  Says the congressional ethics investigation against him was conducted by a very partisan political committee in a way that related more to the politics of the Democratic Party than to ethics.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 78
# Sample Post:  The Senate version of the health care reform bill allows taxpayer money to pay directly for abortion in federal community health centers funded in the bill.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 79
# Sample Post:  Says unlike Tim Kaine, who investedin education, Indiana Gov. Mike Pence slashed education funding.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 80
# Sample Post:  A COVID-19 case has been diagnosed in Umraniye Hospital Istanbul.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 81
# Sample Post:  A poll taken a few months ago found 70 percent approval or higher for the Act 10 collective bargaining law.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 82
# Sample Post:  Says James Langevin voted to spend $3 billion for a jet engine no one wants.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 83
# Sample Post:  The stand your ground lawcaused the shooting death of Trayvon Martin.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 84
# Sample Post:  Covid rashes are now responsible for hate
#
# Covid-19 skin rash website criticised for lack of BAME examples
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 85
# Sample Post:  Prolonged use of the mask causes hypoxia.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 86
# Sample Post:  Says Having organizations parading as being social welfare organizations and then being involved in the political combat harkens back to why the statute a hundred years ago said that they were prohibited.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 87
# Sample Post:  Man Ordered Family Out On Military Manouevres
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 88
# Sample Post:  Tim Kaine announced he wants to raise taxes on everyone.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 89
# Sample Post:  “Putin has stated Russian citizens (have) 2 options Stay home for 15 days or in jail for 5 years.”
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 90
# Sample Post:  Beware Of A Donald Trump Vaccine
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 91
# Sample Post:  UNICEF releases coronavirus prevention guidelines.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 92
# Sample Post:  Channel 4's Jon Snow is infected with coronavirus.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 93
# Sample Post:  A post claims compulsory vacination violates the principles of bioethics that coronavirus doesn't exist that the PCR test returns many false positives and that influenza vaccine is related to COVID-19.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 94
# Sample Post:  The people who were running the budget, in the Corzine years, decided to steal from the unemployment trust fund. As did other Governors before. We simply dont do that, havent done it, and wont permit it.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 95
# Sample Post:      How many FROM covid 19 How many died because New York and New Jersey screwed the elderly Thats all trumps fault right When trump shut down travel...he's a racist. Trump puts a team together to figure out the virus...its not diverse enough.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 96
# Sample Post:  Since some asked about this, am letting know that I am recommending Checkovir after testing on myself for a month. I find it a life saver in allergic rainy season this year. Was part of testing group. I find logical that it will reduce probability of corona due to antiviral layer
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 97
# Sample Post:  Matarratón tree cures COVID-19
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 98
# Sample Post:  In the health care bill, "The 'Health Choices Commissioner' will decide health benefits for you. You will have no choice. None."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 99
# Sample Post:  “COVID barely kills anyone,” says man who would probably be pretty annoyed if we killed him
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 100
# Sample Post:  Photo shows the last meeting of a Turkish doctor who died due to COVID-19 with his child in Munich.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 101
# Sample Post:  The city of Charlotte passed a bathroom ordinance mandate on every private-sector employer in Charlotte.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 102
# Sample Post:  Gov. Scott Walker is helping pay for the criminal defense of a man accused of boy rape.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 103
# Sample Post:  Gov. Scott Walker is helping pay for the criminal defense of a man accused of boy rape.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 104
# Sample Post:  Says the state “health secretary says don't go to hospitals or clinics now the tourism secretary says don't recreate.”
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 105
# Sample Post:  The health care reform plan would set limits similar to the socialized system in Britain, where people are allowed to die if their treatment would cost more than $22,000.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 106
# Sample Post:  A hidden provision in Obamacare taxes sporting goods as medical devices.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 107
# Sample Post:  “A virus is a blessing that sucks.” -ClickHole and Anonymous (collaboration)
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 108
# Sample Post:  Quinine found in tonic water along with 50-100mg of zinc daily will kill COVID-19. Hydroxychloroquine is the synthetic version of Quinine. Drink some fresh squeezed lemon juice with your tonic water. You'll be GOLDEN.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 109
# Sample Post:  An audio file by an alleged worker at a health institution in Rio de Janeiro. She says that healthcare workers on public institutions in Rio are forced to state whether a patient has COVID-19 or not even before he sees a doctor. This was allegedly being done to artificially inflate the number of cases.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 110
# Sample Post:  President Barack Obama "signed the medical appliance tax bill that forced companies to outsource manufacturing of masks gowns gloves and ventilaors [sic] to China Europe and Russia to avoid the tax.”
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 111
# Sample Post:  Says Sen. JeanneShaheens wealth has surged while in public office.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 112
# Sample Post:  NEWS! Government finalising plans to comprehensively blame EU for Coronavirus
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 113
# Sample Post:  Veterans can now download their electronic medical records with a click of the mouse.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 114
# Sample Post:  As tuberculosis shaped modernism, so COVID-19 and our collective experience of staying inside for months on end will influence architecture’s near future,  writes.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 115
# Sample Post:  U.S. military involvement in Libya allowed thousands of surface-to-air missiles to fall into the hands of radical Islamists.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 116
# Sample Post:  Weve already lost $500 million in economic impact from HB2 fallout in North Carolina.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 117
# Sample Post:  Says U.S. Rep. Charles Bass wants to privatize Social Security.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 118
# Sample Post:  As tuberculosis shaped modernism, so COVID-19 and our collective experience of staying inside for months on end will influence architecture’s near future,  writes.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 119
# Sample Post:  In Florida, theyre already talking about how the Ryan-Romney plan will end Medicare and replace it with a voucher.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 120
# Sample Post:  Coronavirus can be cured by sniffing clove and camphor and by drinking water, the virus will go to the stomach and the acid in the stomach will kill the virus.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 121
# Sample Post:  Trump offers to pardon coronavirus
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 122
# Sample Post:  There are "15 minors admitted" because of COVID-19 in the Infanta Sofía Hospital in Madrid and three in the "Talavera hospital".
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 123
# Sample Post:  All India lock down increased till 4th may...
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 124
# Sample Post:  There are over 700,000 Americans on some watch list or another that would all be captured in a Democratic amendment intended to stop suspected terrorists from buying guns.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 125
# Sample Post:  The coronavirus "snuck up on us” adding that it is “a very unforeseen thing.”
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 126
# Sample Post:  Says that when Democrats controlled Congress and the White House, federal spending as a share of the Gross Domestic Product leapt from 18.2 percent in 2001 to 25.2 percent in 2009 -- the largest such increase in any eight-year period since World War II.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 127
# Sample Post:  In the United States, 50 percent of social services are provided by the Catholic church.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 128
# Sample Post:  “Italian Parliament Calls For The Arrest of Bill Gates”
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 129
# Sample Post:  A year since the Recovery Summer, there has been been a fall, winter and spring of no recovery.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 130
# Sample Post:  Says George Washington said a free people should be armed to guard against government tyranny.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 131
# Sample Post:  Under a proposed bill, a $100,000 homes flood insurance premium would be maybe $200 or $300 annually.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 132
# Sample Post:  Coronavirus does not affect people with 'O+' blood type.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 133
# Sample Post:  The data scientist who designed Florida's COVID-19 dashboard — a mobile friendly, has been removed from her position because she refused to censor data and manipulate numbers.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 134
# Sample Post:  Says Anthony Faucis statement that the coronavirus death rate is 10 times that of the seasonal flu is a claim without any scientific basis."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 135
# Sample Post:  _Israel has no deaths from COVID-19; tea made of lemon and bicarbonate can cure coronavirus._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 136
# Sample Post:  Coronavirus Pandemic May Be Cut Short Due to Americans’ Short Attention Span
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 137
# Sample Post:  Billionaire Clive Palmer has taken out ads in major mastheads spruiking the benefits of hydroxychloroquine as a  treatment. And is Bill Gates trying to microchip us all (Spoiler alert he's not). All this in the latest issue of :
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 138
# Sample Post:  Boyce gave (a lobbyists) wife a sensitive job in the treasurers office, a job Boyce admitted he only made available at their mosque.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 139
# Sample Post:  Mass disinfection of people using a chemical solution will eradicate COVID-19
# ---------------------------------------------------------------------------
# ServiceUnavailableError                   Traceback (most recent call last)
# /tmp/ipykernel_70373/3922982128.py in <module>
#       2 for i in range(0, one_shot_iterations):
#       3     print('One-Shot Interation :',i)
# ----> 4     act_label_list,  pre_label_list= one_shot_learning()
#       5     results = pd.DataFrame({'Actual': act_label_list, 'Predicted': pre_label_list})
#       6
#
# /tmp/ipykernel_70373/4010499152.py in one_shot_learning()
#      28
#      29         prompt = prompt_one_shot.format(sample_post['post'])
# ---> 30         result = oneshot_classify_text(prompt)
#      31         print(f"Actual Label: {sample_post['label']}")
#      32         print(f"Predicted Label: {result}")
#
# /tmp/ipykernel_70373/1261982396.py in oneshot_classify_text(prompt)
#       1 def oneshot_classify_text(prompt):
# ----> 2     completion = openai.ChatCompletion.create(
#       3         model="gpt-3.5-turbo",
#       4         messages=[
#       5             {"role": "system", "content": "Label the text as 'Deception' or 'Truth'"},
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     296             request_timeout=request_timeout,
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#     300
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     698         else:
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#     702                     result.status_code,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     741
#     742         if rcode == 503:
# --> 743             raise error.ServiceUnavailableError(
#     744                 "The server is overloaded or not ready yet.",
#     745                 rbody,
#
# ServiceUnavailableError: The server is overloaded or not ready yet.

# %% [markdown]
# ### Evaluate One-Shot Classification Results on a Full Dataset

# %%
results_from_file = pd.read_csv(os.path.join(base_path,'result_one_shot','0_oneshot_results.csv'))

# Extract the actual and predicted labels from the DataFrame
actual_labels_from_file = results_from_file['Actual'].tolist()
predicted_labels_from_file = results_from_file['Predicted'].tolist()

# Calculate the accuracy, precision, recall, and F1-score
accuracy = accuracy_score(actual_labels_from_file, predicted_labels_from_file)
precision = precision_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
recall = recall_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
f1 = f1_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')

# Print the results
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")

# %%
# Initialize variables to calculate averages
total_accuracy = 0
total_precision = 0
total_recall = 0
total_f1 = 0
num_files = 0

base_path = ""  # Set the base path to your directory

for filename in os.listdir(os.path.join(base_path, 'result_one_shot')):
    if filename.endswith('_oneshot_results.csv'):
        num_files += 1

        results_from_file = pd.read_csv(os.path.join(base_path, 'result_one_shot', filename))

        # Extract the actual and predicted labels from the DataFrame
        actual_labels_from_file = results_from_file['Actual'].tolist()
        predicted_labels_from_file = results_from_file['Predicted'].tolist()

        # Calculate the accuracy, precision, recall, and F1-score
        accuracy = accuracy_score(actual_labels_from_file, predicted_labels_from_file)
        precision = precision_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
        recall = recall_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
        f1 = f1_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')

        total_accuracy += accuracy
        total_precision += precision
        total_recall += recall
        total_f1 += f1

# Calculate the average accuracy, precision, recall, and F1-score
avg_accuracy = total_accuracy / num_files
avg_precision = total_precision / num_files
avg_recall = total_recall / num_files
avg_f1 = total_f1 / num_files

# Print the average results
print(f"Average Accuracy: {avg_accuracy:.2f}")
print(f"Average Precision: {avg_precision:.2f}")
print(f"Average Recall: {avg_recall:.2f}")
print(f"Average F1-score: {avg_f1:.2f}")

overall_oneshot_result =[]
overall_oneshot_result.append(round(avg_accuracy, 2))
overall_oneshot_result.append(round(avg_precision, 2))
overall_oneshot_result.append(round(avg_recall, 2))
overall_oneshot_result.append(round(avg_f1, 2))

# %% [markdown]
# ## Few-shot Classification

# %%
def fewshot_classify_text(prompt):
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Label the text as 'Deception' or 'Truth'"},
            {"role": "user", "content": prompt}
        ],
        max_tokens=200,
        temperature=0.5,
        stop=[':', "."]
    )
    prediction = completion.choices[0].message['content'].strip()
    label = prediction.split()[0]
    return label

# %%
def few_shot_learning(num_few):
    # Initialize empty lists to store actual and predicted labels
    actual_label_list = []
    predicted_label_list = []
    
    # obtain "num_few" randomly samples from each class and store in selected_sample 
    # the remaining samples stored in remaining_samples_dataset
    selected_samples, remaining_samples_dataset = select_samples(num_few)
    
    #seperate the samples based on their label
    deceptive_class_sample = selected_samples[selected_samples['label'] == 'Deception']
    truth_class_sample = selected_samples[selected_samples['label'] == 'Truth']
    
    deceptive_fewshot = deceptive_class_sample['post']
    truth_fewshot = truth_class_sample['post']

    # Few-shot learning
    prompt_few_shot = "Below are several social media posts, each labeled as either Deception or Truth:\n"

    for i in range(num_few):
        prompt_few_shot += f"Deception: {deceptive_fewshot.iloc[i]}\n"
        prompt_few_shot += f"Truth: {truth_fewshot.iloc[i]}\n"

    prompt_few_shot += "Determine if the following post is either Deception or Truth: \"{}\""

    for i in range(0, len(remaining_samples_dataset)):
        print('sample number :', i)
        sample_post = remaining_samples_dataset.loc[i]
        print('Sample Post: ',sample_post['post'])

        prompt = prompt_few_shot.format(sample_post['post'])
        result = fewshot_classify_text(prompt)
        print(f"Actual Label: {sample_post['label']}")
        print(f"Predicted Label: {result}")
        actual_label_list.append(sample_post['label'])
        predicted_label_list.append(result)
    results = pd.DataFrame({'Actual': actual_label_list, 'Predicted': predicted_label_list})
    output_file = str(num_few)+'_fewshot_results.csv'
    results.to_csv(os.path.join(base_path,'result_few_shot',output_file), index=False)

# %%
no_Fewshot_Reference = 2
few_shot_learning(no_Fewshot_Reference)
# Out:
# sample number : 0
# Sample Post:     Lucky for you grapefruit doesn’t make quinine. Hydtoxychloroquine is a different chemical. You’re not getting any.
# Both are somewhat effective anti-malarial treatments but have side effects.
# They have no effect on SARS-CoV-2 virus that causes Covid-19.
#
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 1
# Sample Post:  Nevada Democratic Party leaders hijacked the process on the floor of the state convention ignoring the regular procedure and ramming through what they wanted to do.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 2
# Sample Post:  Says a group estimates that the annual cost to Oregon taxpayers for government services to illegal aliens, after any income tax revenue from them, is $1 billion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 3
# Sample Post:  There is long historical precedent for a Supreme Court with fewer justices.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 4
# Sample Post:  Says Chuck Hagel has called for an end to our nuclear program.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 5
# Sample Post:  A claim that the novel coronavirus was never detected in the major Chinese cities of Beijing and Shanghai has been shared repeatedly on Facebook Twitter and Instagram.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 6
# Sample Post:  Action by the Milwaukee County Board will provide the County Executive with the same level of security as the Governor and the Mayor of Milwaukee while saving taxpayers $300,000.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 7
# Sample Post:  Toledo is fourth in the nation behind much bigger cities Miami, Las Vegas, Portland in number of human trafficking arrests and rescues.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 8
# Sample Post:  After Fahrenheit 9/11 came out, "Bush's approval rating never was better, it only got worse."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 9
# Sample Post:  An analysis showed that Bernie Sanders would have won the Democratic nomination if it were not for the Super Delegates.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 10
# Sample Post:  Back in the Great Recession, when millions of jobs across America hung in the balance, Donald Trump said rescuing the auto industry didnt really matter very much. He said, and I quote again, Let it go.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 11
# Sample Post:  Bank of America could create 878,300 jobs with benefits if they spent their 2010 bonuses on job creation.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 12
# Sample Post:  Says only about 2 percent of gunsales in Virginia are not subject to background checks.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 13
# Sample Post:  Video of migrants in a overcrowded train from Mumbai to West Bengal on 10 May 2020 amid COVID-19 social distancing restrictictions.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 14
# Sample Post:  Tinder Adds New “COVID-19 Positive” Option For Users
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 15
# Sample Post:  Great Idea for Mass Steam Inhalation during this
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 16
# Sample Post:  In 2009, Jim Doyle and the Democrats rushed through a budget repair bill with billions in tax increases and held no public hearings.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 17
# Sample Post:  She is the only candidate who has stood by our community and immigration reform from the beginning.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 18
# Sample Post:  A police officer in Bihar's Hajipur jail has been affected with coronavirus.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 19
# Sample Post:  Obama's one education accomplishment was "legislation to teach 'comprehensive sex education' to kindergartners."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 20
# Sample Post:  Saddam Hussein at a meeting in the nineties reported that the US threatened to quit the Corona virus on Iraq
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 21
# Sample Post:  Ukraine was a nuclear-armed state. They gave away their nuclear arms with the understanding that we would protect them.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 22
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 23
# Sample Post:  With a stroke of a pen, the (U.S. Supreme Court) decided to overrule the 100-year-old ban on corporate expenditures.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 24
# Sample Post:  Says that under President Barack Obamas health care law, your insurance premiums could go up by 200 percent and cost as much as a new Explorer.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 25
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 26
# Sample Post:  Donald Trumps been completely consistent about his plan for nonviolent undocumented immigrants.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 27
# Sample Post:  Now, theyre doing tests on airlines " very strong tests " for getting on, getting off. Theyre doing tests on trains " getting on, getting off.�
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 28
# Sample Post:  The Government Accountability Office estimated (Obamacare) will add to the long-term deficit by $6.2 trillion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 29
# Sample Post:  In the second consecutive day India reports over 50000 new infections taking the overall confirmed case tally to 16.3 lakh. Directorate General of Civil Aviation extends the suspension of commercial international flights to India till 31 August.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 30
# Sample Post:  _A video has been viewed thousands of times in multiple posts on Facebook Twitter and YouTube in May 2020 alongside a claim it shows crows coming to Texas� after attacking Wuhan China�. The posts were shared as countries worldwide continue to fight the spread of the novel coronavirus which was first detected in Wuhan in December 2019._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 31
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 32
# Sample Post:  Everyone knows that we're facing a real crisis from the coronavirus. But do you know how we got here and what we need to do next Ron Klain, former White House Ebola Response Coordinator, breaks it down for us:
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 33
# Sample Post:  Bob Menendez actually voted in favor of higher taxes more than 70 times!
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 34
# Sample Post:  Oklahoma 100% coronavirus test rate after Trump Tulsa rally.�
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 35
# Sample Post:  President Barack Obama is the first president to keep a dog-trainer on retainer for $102,000 a year at taxpayer expense.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 36
# Sample Post:  In the Florida Republican primary, "we got a very large percentage of the, quote, conservative vote."
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 37
# Sample Post:  Dr. VK Srinivas Vice-President of Bharath Biotech He is taking first injection of COVID 19 vaccine. They have confidence in their product
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 38
# Sample Post:  Good people of Twitter, and especially those with young children. If you or your partner have had symptoms during the lockdown, which best describes your approach:
# Actual Label: Deception
# Predicted Label: Cannot
# sample number : 39
# Sample Post:  Dr. Li Wenliang (the Chinese whistleblower doctor) has proposed that drinking tea can cure COVID-19.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 40
# Sample Post:  Holly Turner... still takes her homestead (property tax) exemption in Fort Worth.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 41
# Sample Post:  In December 2019 Italian politician Beppe Grillo wore a protective mask in public. Some people said that he did that because the Chinese Embassy had warned him about coronavirus.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 42
# Sample Post:  Italy finds home remedy for Covid’19 / 500gms aspirin dissolved with lemon juice boiled with honey, it is taken hot.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 43
# Sample Post:     Sir i was infected in mid August of covid 19 and after suffering for 8 days was prescribed for Favipiravir fabiflu and was cured.
# In 36 hours most of my symptoms were gone fully recovered in 7 days
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 44
# Sample Post:  I also voted 98 percent of the time with Republicans in the Oregon Legislature.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 45
# Sample Post:  Decision of lockdown was timely, curve has begun to flatten
#
# The nation has shown that lockdown has been effective, , containing  infection and slowing down doubling rate
#
# We need to build on these gains
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 46
# Sample Post:  Italian doctors say coronavirus is bacteria.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 47
# Sample Post:  A person with a cold or flu will test positive for COVID-19
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 48
# Sample Post:  This virus must be old because the label on a bottle of disinfectant from 2015 shows "coronavirus“.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 49
# Sample Post:  Newgard owed more than $13,000 for unpaid taxes on his $1 million Milwaukie apartment complex.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 50
# Sample Post:  Following the catastrophic, cascading collapse of major investment banks on Wall Street in 2007.....Nobody was prosecuted, no hearings were held and no reforms were implemented.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 51
# Sample Post:  Meditate Your Way Through Covid 19 With Tracy Honeycomb
#
#
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 52
# Sample Post:  Honduras's first confirmed case traveled to Taiwan earlier which means there is a severe community transmission in Taiwan.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 53
# Sample Post:  The only reason the unemployment rate is going down is because twice as many people dropped out of the employment pool as the number of jobs were created.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 54
# Sample Post:  She hasn't run a corner store. She hasn't run a state. She hasn't run a city. She has never run anything.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 55
# Sample Post:  Videos show pigs being buried in China due to the coronavirus outbreak.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 56
# Sample Post:  _A vaccine has been developed that cures Covid-19 in just three hours._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 57
# Sample Post:  The job [of correctional officer] lowers your life expectancy . . . Metropolitan did a study in, I believe it was 1998, and the life expectancy was 58.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 58
# Sample Post:  In the health care bill, were now offering insurance for dogs.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 59
# Sample Post:  In Catherine Cortez Mastos last term as attorney general, Nevada murder went up 11 percent, robbery went up 28 percent, rape 51 percent. When Cortez Masto left office, Nevada ranked as Americas third most dangerous state.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 60
# Sample Post:  Four million women have fallen into poverty in the last six years.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 61
# Sample Post:  Strange coincidence that all worst affected Covid19 cases are along the same Latitude 40ํ :
# From left:
# France Italy Iran Wuhan S.Korea Japan Seattle Washington NewYork.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 62
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 63
# Sample Post:  The U.S. wont default, because default means that you dont pay your creditors. And it takes about 10 percent of the money thats coming in right now to pay interest to bondholders.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 64
# Sample Post:  Trump says if we stopped COVID-19 testing right now we’d have very few cases if any. Pants on Fire!
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 65
# Sample Post:  We will all come out stronger from this   . Just
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 66
# Sample Post:  Squeezing hot lemon water cures corona virus infection.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 67
# Sample Post:  We dont allow filming inside of the City Hall unless there is a specific reason.
# ---------------------------------------------------------------------------
# ServiceUnavailableError                   Traceback (most recent call last)
# /tmp/ipykernel_70373/68926586.py in <module>
#       1 no_Fewshot_Reference = 2
# ----> 2 few_shot_learning(no_Fewshot_Reference)
#
# /tmp/ipykernel_70373/800881255.py in few_shot_learning(num_few)
#      30
#      31         prompt = prompt_few_shot.format(sample_post['post'])
# ---> 32         result = fewshot_classify_text(prompt)
#      33         print(f"Actual Label: {sample_post['label']}")
#      34         print(f"Predicted Label: {result}")
#
# /tmp/ipykernel_70373/4183480067.py in fewshot_classify_text(prompt)
#       1 def fewshot_classify_text(prompt):
# ----> 2     completion = openai.ChatCompletion.create(
#       3         model="gpt-3.5-turbo",
#       4         messages=[
#       5             {"role": "system", "content": "Label the text as 'Deception' or 'Truth'"},
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     296             request_timeout=request_timeout,
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#     300
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     698         else:
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#     702                     result.status_code,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     741
#     742         if rcode == 503:
# --> 743             raise error.ServiceUnavailableError(
#     744                 "The server is overloaded or not ready yet.",
#     745                 rbody,
#
# ServiceUnavailableError: The server is overloaded or not ready yet.

# %%
results_from_file = pd.read_csv(os.path.join(base_path,'result_few_shot',str(no_Fewshot_Reference)+'_fewshot_results.csv'))

# Extract the actual and predicted labels from the DataFrame
actual_labels_from_file = results_from_file['Actual'].tolist()
predicted_labels_from_file = results_from_file['Predicted'].tolist()

# Calculate the accuracy, precision, recall, and F1-score
accuracy = accuracy_score(actual_labels_from_file, predicted_labels_from_file)
precision = precision_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
recall = recall_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
f1 = f1_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')

# Print the results
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
first_fewshot_result =[]
first_fewshot_result.append(round(accuracy, 2))
first_fewshot_result.append(round(precision, 2))
first_fewshot_result.append(round(recall, 2))
first_fewshot_result.append(round(f1, 2))

# %%
no_Fewshot_Reference = 32
few_shot_learning(no_Fewshot_Reference)
# Out:
# sample number : 0
# Sample Post:     Lucky for you grapefruit doesn’t make quinine. Hydtoxychloroquine is a different chemical. You’re not getting any.
# Both are somewhat effective anti-malarial treatments but have side effects.
# They have no effect on SARS-CoV-2 virus that causes Covid-19.
#
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 1
# Sample Post:  Nevada Democratic Party leaders hijacked the process on the floor of the state convention ignoring the regular procedure and ramming through what they wanted to do.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 2
# Sample Post:  Says a group estimates that the annual cost to Oregon taxpayers for government services to illegal aliens, after any income tax revenue from them, is $1 billion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 3
# Sample Post:  There is long historical precedent for a Supreme Court with fewer justices.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 4
# Sample Post:  Says Chuck Hagel has called for an end to our nuclear program.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 5
# Sample Post:  A claim that the novel coronavirus was never detected in the major Chinese cities of Beijing and Shanghai has been shared repeatedly on Facebook Twitter and Instagram.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 6
# Sample Post:  Action by the Milwaukee County Board will provide the County Executive with the same level of security as the Governor and the Mayor of Milwaukee while saving taxpayers $300,000.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 7
# Sample Post:  Toledo is fourth in the nation behind much bigger cities Miami, Las Vegas, Portland in number of human trafficking arrests and rescues.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 8
# Sample Post:  After Fahrenheit 9/11 came out, "Bush's approval rating never was better, it only got worse."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 9
# Sample Post:  An analysis showed that Bernie Sanders would have won the Democratic nomination if it were not for the Super Delegates.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 10
# Sample Post:  Back in the Great Recession, when millions of jobs across America hung in the balance, Donald Trump said rescuing the auto industry didnt really matter very much. He said, and I quote again, Let it go.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 11
# Sample Post:  Bank of America could create 878,300 jobs with benefits if they spent their 2010 bonuses on job creation.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 12
# Sample Post:  Says only about 2 percent of gunsales in Virginia are not subject to background checks.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 13
# Sample Post:  Video of migrants in a overcrowded train from Mumbai to West Bengal on 10 May 2020 amid COVID-19 social distancing restrictictions.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 14
# Sample Post:  Tinder Adds New “COVID-19 Positive” Option For Users
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 15
# Sample Post:  Great Idea for Mass Steam Inhalation during this
# Actual Label: Deception
# Predicted Label: Cannot
# sample number : 16
# Sample Post:  In 2009, Jim Doyle and the Democrats rushed through a budget repair bill with billions in tax increases and held no public hearings.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 17
# Sample Post:  She is the only candidate who has stood by our community and immigration reform from the beginning.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 18
# Sample Post:  A police officer in Bihar's Hajipur jail has been affected with coronavirus.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 19
# Sample Post:  Obama's one education accomplishment was "legislation to teach 'comprehensive sex education' to kindergartners."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 20
# Sample Post:  Saddam Hussein at a meeting in the nineties reported that the US threatened to quit the Corona virus on Iraq
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 21
# Sample Post:  Ukraine was a nuclear-armed state. They gave away their nuclear arms with the understanding that we would protect them.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 22
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 23
# Sample Post:  With a stroke of a pen, the (U.S. Supreme Court) decided to overrule the 100-year-old ban on corporate expenditures.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 24
# Sample Post:  Says that under President Barack Obamas health care law, your insurance premiums could go up by 200 percent and cost as much as a new Explorer.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 25
# Sample Post:  The signers of the Declaration of Independence were "brave people, most of whom, by the way, were clergymen."
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 26
# Sample Post:  Donald Trumps been completely consistent about his plan for nonviolent undocumented immigrants.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 27
# Sample Post:  Now, theyre doing tests on airlines " very strong tests " for getting on, getting off. Theyre doing tests on trains " getting on, getting off.�
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 28
# Sample Post:  The Government Accountability Office estimated (Obamacare) will add to the long-term deficit by $6.2 trillion.
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 29
# Sample Post:  In the second consecutive day India reports over 50000 new infections taking the overall confirmed case tally to 16.3 lakh. Directorate General of Civil Aviation extends the suspension of commercial international flights to India till 31 August.
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 30
# Sample Post:  _A video has been viewed thousands of times in multiple posts on Facebook Twitter and YouTube in May 2020 alongside a claim it shows crows coming to Texas� after attacking Wuhan China�. The posts were shared as countries worldwide continue to fight the spread of the novel coronavirus which was first detected in Wuhan in December 2019._
# Actual Label: Deception
# Predicted Label: Deception
# sample number : 31
# Sample Post:   Dr Shi (en het Wuhan Institute of Virology) deden mee aan dit onderzoek:
# Utilizing the SARS-CoV infectious clone, we generated and characterized a chimeric virus expressing the spike of bat coronavirus SHC014 in a mouse adapted SARS-CoV backbone.
#
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 32
# Sample Post:  Everyone knows that we're facing a real crisis from the coronavirus. But do you know how we got here and what we need to do next Ron Klain, former White House Ebola Response Coordinator, breaks it down for us:
# Actual Label: Deception
# Predicted Label: Truth
# sample number : 33
# Sample Post:  Bob Menendez actually voted in favor of higher taxes more than 70 times!
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_70373/136236142.py in <module>
#       1 no_Fewshot_Reference = 32
# ----> 2 few_shot_learning(no_Fewshot_Reference)
#
# /tmp/ipykernel_70373/800881255.py in few_shot_learning(num_few)
#      30
#      31         prompt = prompt_few_shot.format(sample_post['post'])
# ---> 32         result = fewshot_classify_text(prompt)
#      33         print(f"Actual Label: {sample_post['label']}")
#      34         print(f"Predicted Label: {result}")
#
# /tmp/ipykernel_70373/4183480067.py in fewshot_classify_text(prompt)
#       1 def fewshot_classify_text(prompt):
# ----> 2     completion = openai.ChatCompletion.create(
#       3         model="gpt-3.5-turbo",
#       4         messages=[
#       5             {"role": "system", "content": "Label the text as 'Deception' or 'Truth'"},
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     296             request_timeout=request_timeout,
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#     300
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     698         else:
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#     702                     result.status_code,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     761         stream_error = stream and "error" in resp.data
#     762         if stream_error or not 200 <= rcode < 300:
# --> 763             raise self.handle_error_response(
#     764                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     765             )
#
# RateLimitError: Rate limit reached for default-gpt-3.5-turbo in organization org-QRBhaEmeToc5CGb68gEDCHQf on tokens per min. Limit: 60000 / min. Please try again in 1ms. Contact us through our help center at help.openai.com if you continue to have issues.

# %%
results_from_file = pd.read_csv(os.path.join(base_path,'result_few_shot',str(no_Fewshot_Reference)+'_fewshot_results.csv'))

# Extract the actual and predicted labels from the DataFrame
actual_labels_from_file = results_from_file['Actual'].tolist()
predicted_labels_from_file = results_from_file['Predicted'].tolist()

# Calculate the accuracy, precision, recall, and F1-score
accuracy = accuracy_score(actual_labels_from_file, predicted_labels_from_file)
precision = precision_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
recall = recall_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
f1 = f1_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')

# Print the results
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")

second_fewshot_result =[]
second_fewshot_result.append(round(accuracy, 2))
second_fewshot_result.append(round(precision, 2))
second_fewshot_result.append(round(recall, 2))
second_fewshot_result.append(round(f1, 2))

# %% [markdown]
# ### Performance between different Fewshot values

# %%
# setting the bar width
barWidth = 0.25

# setting the positions of the bars on x-axis
r1 = np.arange(len(first_fewshot_result))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# plotting the bars
bar1 = plt.bar(r1, first_fewshot_result, color='#7f6d5f', width=barWidth, edgecolor='grey', label='First_FewShot')
bar2 = plt.bar(r2, second_fewshot_result, color='#557f2d', width=barWidth, edgecolor='grey', label='Second__FewShot')

# Adding values inside the bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2.0, height / 2.0,
                 '{0:.2f}'.format(height), ha='center', va='center', color='white', fontweight='bold')

autolabel(bar1)
autolabel(bar2)

# adding the labels
plt.xlabel('Metrics', fontweight='bold', fontsize=15)
plt.ylabel('Values', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(first_fewshot_result))], ['Accuracy', 'Precision', 'Recall', 'F1 Score'])

# creating legend
plt.legend()

# showing the plot
plt.show()

# %%
# Initialize variables to calculate averages
total_accuracy = 0
total_precision = 0
total_recall = 0
total_f1 = 0
num_files = 0

base_path = ""  # Set the base path to your directory

for filename in os.listdir(os.path.join(base_path, 'result_few_shot')):
    if filename.endswith('_fewshot_results.csv'):
        num_files += 1

        results_from_file = pd.read_csv(os.path.join(base_path, 'result_few_shot', filename))

        # Extract the actual and predicted labels from the DataFrame
        actual_labels_from_file = results_from_file['Actual'].tolist()
        predicted_labels_from_file = results_from_file['Predicted'].tolist()

        # Calculate the accuracy, precision, recall, and F1-score
        accuracy = accuracy_score(actual_labels_from_file, predicted_labels_from_file)
        precision = precision_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
        recall = recall_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')
        f1 = f1_score(actual_labels_from_file, predicted_labels_from_file, pos_label='Deception')

        total_accuracy += accuracy
        total_precision += precision
        total_recall += recall
        total_f1 += f1

# Calculate the average accuracy, precision, recall, and F1-score
avg_accuracy = total_accuracy / num_files
avg_precision = total_precision / num_files
avg_recall = total_recall / num_files
avg_f1 = total_f1 / num_files

# Print the average results
print(f"Average Accuracy: {avg_accuracy:.2f}")
print(f"Average Precision: {avg_precision:.2f}")
print(f"Average Recall: {avg_recall:.2f}")
print(f"Average F1-score: {avg_f1:.2f}")
overall_fewshot_result =[]
overall_fewshot_result.append(round(avg_accuracy, 2))
overall_fewshot_result.append(round(avg_precision, 2))
overall_fewshot_result.append(round(avg_recall, 2))
overall_fewshot_result.append(round(avg_f1, 2))

# %% [markdown]
# ### Overall Performance Graph average on each interation

# %%
# setting the bar width
barWidth = 0.25

# setting the positions of the bars on x-axis
r1 = np.arange(len(overall_zeroshot_result))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# plotting the bars
bar1 = plt.bar(r1, overall_zeroshot_result, color='#7f6d5f', width=barWidth, edgecolor='grey', label='Zero Shot')
bar2 = plt.bar(r2, overall_oneshot_result, color='#557f2d', width=barWidth, edgecolor='grey', label='One Shot')
bar3 = plt.bar(r3, overall_fewshot_result, color='#2d7f5e', width=barWidth, edgecolor='grey', label='Few Shot')

# Adding values inside the bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2.0, height / 2.0,
                 '{0:.2f}'.format(height), ha='center', va='center', color='white', fontweight='bold')

autolabel(bar1)
autolabel(bar2)
autolabel(bar3)

# adding the labels
plt.xlabel('Metrics', fontweight='bold', fontsize=15)
plt.ylabel('Values', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(overall_zeroshot_result))], ['Accuracy', 'Precision', 'Recall', 'F1 Score'])

# creating legend
plt.legend()

# showing the plot
plt.show()
